# %%
import sys
import keyword
import operator
from datetime import datetime
import os

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [markdown]
# Identifiers

# %%
1var =10
# Out:
#   Cell In[8], line 1
#     1var =10
#     ^
# SyntaxError: invalid decimal literal

# %%
var1 =10
var1
# Out:
# 10

# %%
var2@ =35
# Out:
#   Cell In[10], line 1
#     var2@ =35
#           ^
# SyntaxError: invalid syntax

# %%
import = 125#
# Out:
#   Cell In[11], line 1
#     import = 125#
#            ^
# SyntaxError: invalid syntax

# %%
Val_ = 99
Val_
# Out:
# 99

# %%
val_ =20
val_
# Out:
# 20

# %% [markdown]
# Comments in Python

# %%
# This is staring of python basics
a=5
a
# Out:
# 5

# %%
# Multil
#line
#comment
used = 10
used
# Out:
# 10

# %%
'Multiline'
# Out:
# 'Multiline'

# %%
"Multiline 
for used"
# Out:
#   Cell In[20], line 1
#     "Multiline
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'''Multiline for testing
and to use again and again'''
# Out:
# 'Multiline for testing\nand to use again and again'

# %% [markdown]
# Statements
# Instructions that a Python interpreter can execute.

# %%
p=20
q=20
r=q
print(id(p), id(q))
p, type(p), hex(id(p))
# Out:
# 140719386502664 140719386502664
# (20, int, '0x7ffbc90ba608')

# %%
r, type(r), hex(id(r))
# Out:
# (20, int, '0x7ffbc90ba608')

# %%
p = p+10
p
# Out:
# 30

# %%
p, type(p), hex(id(p))
# Out:
# (30, int, '0x7ffbc90ba748')

# %% [markdown]
# ## Variable Assignment##

# %%
intvar = 10
floatvar = 20.5
strvar = " I love india"
print(intvar)
print(floatvar)
print(strvar)
# Out:
# 10
# 20.5
#  I love india

# %%
intvar , floatvar , strvar = 20, 15.5, 'I am form India'
print(intvar)
print(floatvar)
print(strvar)
# Out:
# 20
# 15.5
# I am form India

# %%
p1=p2=p3=p4=p5=45
print( p1,p2,p3,p4,p5)
# Out:
# 45 45 45 45 45

# %% [markdown]
# ## Datatype

# %%
intvar1 = 10
print(intvar1)
print(type(intvar1))
print(sys.getsizeof(intvar1))
# Out:
# 10
# <class 'int'>
# 28

# %%
print(intvar1, "is integer?", isinstance(intvar1,int))
# Out:
# 10 is integer? True

# %%
intvar2 = 10.5
print(intvar2)
print(type(intvar2))
print(sys.getsizeof(intvar2))
print(intvar2, "is integer?", isinstance(intvar2,int))
# Out:
# 10.5
# <class 'float'>
# 24
# 10.5 is integer? False

# %%
val3 = 3+5j
print(val3)
print(type(val3))
print(sys.getsizeof(val3))
print(val3, "Is complex type", isinstance(val3,complex))
# Out:
# (3+5j)
# <class 'complex'>
# 32
# (3+5j) Is complex type True

# %%
print(sys.getsizeof(int()))
print(sys.getsizeof(float()))
print(sys.getsizeof(complex()))
# Out:
# 28
# 24
# 32

# %% [markdown]
# ## Boolean

# %%
bool1 = True

# %%
bool2 = False

# %%
print(type(bool1))
# Out:
# <class 'bool'>

# %%
isinstance((bool1),bool)
# Out:
# True

# %%
print(bool1(0)
# Out:
#   Cell In[61], line 1
#     print(bool1(0)
#                   ^
# _IncompleteInputError: incomplete input

# %%
bool1(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 bool1(0)
#
# TypeError: 'bool' object is not callable

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %% [markdown]
#  ## String

# %%
str1 = " HEllo Mohan, Welcome to NarashIT"
print(str1)
# Out:
#  HEllo Mohan, Welcome to NarashIT

# %%
str2 = '''    HEllo Mohan, Welcome to
                                        NarashIT  '''
print(str2)
# Out:
#     HEllo Mohan, Welcome to
#                                         NarashIT

# %%
print (str2  * 5)
# Out:
#     HEllo Mohan, Welcome to
#                                         NarashIT     HEllo Mohan, Welcome to
#                                         NarashIT     HEllo Mohan, Welcome to
#                                         NarashIT     HEllo Mohan, Welcome to
#                                         NarashIT     HEllo Mohan, Welcome to
#                                         NarashIT

# %%
len( str2)
# Out:
# 77

# %% [markdown]
# ## String indexing

# %%
str1[8:11]
# Out:
# 'oha'

# %%
string1 = "This is my world"
string1
# Out:
# 'This is my world'

# %%
string1[0:-1]
# Out:
# 'This is my worl'

# %%
string1[len(string1)-1]
# Out:
# 'd'

# %%
len(string1)
# Out:
# 16

# %%
string1[0:4]
# Out:
# 'This'

# %%
string1[5:10]
# Out:
# 'is my'

# %%
string1[-6:]
# Out:
# ' world'

# %%
k = mohan+3J
type(k)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 k = mohan+3J
#       2 type(k)
#
# NameError: name 'mohan' is not defined

# %%
none = 'Delhi'
none
# Out:
# 'Delhi'

# %%
None = 'Delhi'
# Out:
#   Cell In[112], line 1
#     None = 'Delhi'
#     ^
# SyntaxError: cannot assign to None

# %%
val5= a+3j
val5
# Out:
# (5+3j)

# %%
pi = [2,4,5]
qi = [6,7,8]
li = pi+qi
mi = qi+pi
print(li)
print(mi)
# Out:
# [2, 4, 5, 6, 7, 8]
# [6, 7, 8, 2, 4, 5]

# %%
mi[2]=10
mi
# Out:
# [6, 7, 10, 2, 4, 5]

# %%
s1 ="Mohan"
s2 = 'PMK.'
s2+s1
# Out:
# 'PMK.Mohan'

# %%
type(np.non)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 type(np.non)
#
# NameError: name 'np' is not defined

# %%
print(True*2)
# Out:
# 2

# %%
poll_data = 7,
type(poll_data)
# Out:
# tuple

# %%
dict(range(9))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 dict(range(9))
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %%
set(range(9))
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7, 8}

# %%
list(range(9))
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
tuple(range(9))
# Out:
# (0, 1, 2, 3, 4, 5, 6, 7, 8)

# %%
obj_data = ( ) 
type(obj_data)
# Out:
# tuple
