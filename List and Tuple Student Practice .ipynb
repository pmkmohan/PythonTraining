# %% [markdown]
# # List
# 1) List is an ordered sequence of items.
#
# 2) We can have different data types under a list. E.g we can have integer, float and string items in
# a same list.

# %%
list1 =[] # Empty List

# %%
list1
# Out:
# []

# %%
print(type(list1))
# Out:
# <class 'list'>

# %%
list2 =[10 ,30, 40] # List of integers numbers 
list2
# Out:
# [10, 30, 40]

# %%
list3 = [ 10.77, 60.38, 30.66] # lis of float numbers

# %%
list4 = [ 'one','two','three'] # list of strings
list4
# Out:
# ['one', 'two', 'three']

# %%
list5 = [ 'Mohan',25,[50,100],[12,9]]  #Nested list
list5
# Out:
# ['Mohan', 25, [50, 100], [12, 9]]

# %%
list6 =[ 100, 'mohan', 17.256] # list of mixed data types.
list6
# Out:
# [100, 'mohan', 17.256]

# %%
list7 = ['Mohan', 25 ,[50, 100],[150, 90] , {'John' , 'David'}]
list7
# Out:
# ['Mohan', 25, [50, 100], [150, 90], {'David', 'John'}]

# %%
len(list6)
# Out:
# 3

# %%
list2
# Out:
# [10, 30, 40]

# %% [markdown]
# # List Slicing

# %%
list2[0] # Retreive first element of the list
# Out:
# 10

# %%
list4
# Out:
# ['one', 'two', 'three']

# %%
list4[1]
# Out:
# 'two'

# %%
list4[0][1]  # Nested indexing - Access the first character of the first list ele
# Out:
# 'n'

# %%
list4[-1] # Last item of the list
# Out:
# 'three'

# %%
mylist = ['one' , 'two' , 'three' , 'four' , 'five' , 'six' , 'seven' , 'eight']

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mylist[0:3]  # Return all items from 0th to 3rd index location excluding the item
# Out:
# ['one', 'two', 'three']

# %%
mylist[2:5]  # List all items from 2nd to 5th index location excluding the item a
# Out:
# ['three', 'four', 'five']

# %%
mylist[:3] # Return first three items
# Out:
# ['one', 'two', 'three']

# %%
mylist[:2] # return first two items
# Out:
# ['one', 'two']

# %%
mylist[-3:] # Return last three items
# Out:
# ['six', 'seven', 'eight']

# %%
mylist[-1] # Return last item of the list
# Out:
# 'eight'

# %%
mylist[:] # Return whole list
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %% [markdown]
# # Add ( Append) , Remove (POP/ remove) & Change Items

# %%
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mylist.add('nine')
mylist
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 mylist.add('nine')
#       2 mylist
#
# AttributeError: 'list' object has no attribute 'add'

# %%
mylist.append('nine')  # Add an item to the end of the list
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist.insert(9,'ten') # Add item at index location 9 
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten']

# %%
mylist.insert(1,"new one")
mylist
# Out:
# ['one',
#  'new one',
#  'two',
#  'three',
#  'four',
#  'five',
#  'six',
#  'seven',
#  'eight',
#  'nine',
#  'ten']

# %%
mylist.remove('new one') # Remove item "new one"
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten']

# %%
mylist.pop() # POP function removes the last item in the list
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist.pop(0) # POP function with indexin () will removes the 
                # item in the list at the give index here it is 0 so one is removed from teh list
mylist
# Out:
# ['two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist.pop(8) # pop(8), 8th index number is not avilable do we are getting Index error
mylist
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 mylist.pop(8)
#       2 mylist
#
# IndexError: pop index out of range

# %%
mylist.pop(7) # pop(7), 7th index number is removed
mylist
# Out:
# ['two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %% [markdown]
# # Difference between remove nd pop
#  Remove function will remove the value in the list like remove('eight')
#
#  pop functuion will by default remove the last number in the list.
#
#  pop(idex) will remove the item in that index

# %%
del mylist[6]  # Remove item at index location 6
mylist
# Out:
# ['two', 'three', 'four', 'five', 'six', 'seven']

# %% [markdown]
# # Change the values of the list

# %%
mylist[0] = 1
mylist[1] = 2
mylist[2] = 3
mylist
# Out:
# [1, 2, 3, 'five', 'six', 'seven']

# %%
mylist.clear()  # Empty List / Delete all items in the list

# %%
mylist
# Out:
# []

# %%
del mylist # Delete the whole list

# %%
mylist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 mylist
#
# NameError: name 'mylist' is not defined

# %% [markdown]
# # Copy list

# %%
mylist = ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']
mylist
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist1 = mylist  # Create a new reference "mylist1"

# %%
mylist1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
id(mylist), id(mylist1) # The address of both mylist & mylist1 will be the same
# Out:
# (2426020034432, 2426020034432)

# %%
mylist3 = mylist.copy()  # Create a copy of the list  and # The address of mylist3 will be different from mylist
mylist3
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %% [markdown]
# # This shows the difference in agging one to other by =  and using copy function.

# %%
id(mylist), id(mylist1), id(mylist3)
# Out:
# (2426020034432, 2426020034432, 2426019322432)

# %%
mylist[0]
# Out:
# 'one'

# %%
mylist[0] = 1 # list is mutable, ie valuses can be changes 
mylist
# Out:
# [1, 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist1  # mylist1 will be also impacted as it is pointing to the same list
# Out:
# [1, 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %%
mylist3 # Copy of list won't be impacted due to changes made on the original lis
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']

# %% [markdown]
# # Join Lists

# %%
list1 = ['one', 'two', 'three', 'four'] 
list2 = ['five', 'six', 'seven', 'eight']

# %%
list1 , list2
# Out:
# (['one', 'two', 'three', 'four'], ['five', 'six', 'seven', 'eight'])

# %%
list3 = list1+list2 # join two lists by "+" Operator
list3
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
id(list1), id(list2), id(list3)
# Out:
# (2426019702656, 2426019897472, 2426019810496)

# %%
list1.extend(list2)  #Append list2 with list1
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
len(list1)
# Out:
# 8

# %%
print(list1)
print(list2)
print(list3)
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']
# ['five', 'six', 'seven', 'eight']
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list4 =['nine', 'ten']
list1.extend(list4)
list4
# Out:
# ['nine', 'ten']

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten']

# %%
len(list1)
# Out:
# 10

# %%
print(list1)
print(list2)
print(list3)
print(list4)
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten']
# ['five', 'six', 'seven', 'eight']
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']
# ['nine', 'ten']

# %% [markdown]
# # List Membership

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten']

# %%
one in list1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 one in list1
#
# NameError: name 'one' is not defined

# %%
'one' in list1
# Out:
# True

# %%
'one ' in list1 # there is space after one so it is shown as false
# Out:
# False

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten']

# %%
'eight' in list1
# Out:
# True

# %%
'eighteen' in list1
# Out:
# False

# %%
8 in list1
# Out:
# False

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten']

# %%
if 'two' in list1:
    print(" Two is present in the list1")
else:
    print(" Two is not present in the list1")
# Out:
#  Two is present in the list1

# %%
x = input(" Give the numbe in words to find in the list1")
if x in list1:
    print(x,"is in the list1")
else:
    print(x, " us not in the list1")
# Out:
#  Give the numbe in words to find in the list1 five
# five is in the list1

# %% [markdown]
# # Reverse & Sort List

# %%
list = ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']
list
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
list.reverse() # Reverse the list
list
# Out:
# ['eight', 'seven', 'six', 'five', 'four', 'three', 'two', 'one']

# %%
# using Slicing option to reverce the list.
list[::-1]
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight']

# %%
mylist3 = [9,5,2,99,12,88,34] 
mylist3.sort() # Sort list in ascending order it work with the smae datatype
mylist3
# Out:
# [2, 5, 9, 12, 34, 88, 99]

# %%
mylist3.sort(reverse=True)  # Sort list in descending order
mylist3
# Out:
# [99, 88, 34, 12, 9, 5, 2]

# %%
mylist4 = [88,65,33,21,11,98] 
mylist5 = (mylist4)
mylist4.sort()
print(mylist4)
print(mylist5)
print(mylist4)
# Out:
# [11, 21, 33, 65, 88, 98]
# [11, 21, 33, 65, 88, 98]
# [11, 21, 33, 65, 88, 98]

# %%
id(mylist4),id(mylist5)
# Out:
# (2426020031936, 2426024570944)

# %%
list1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', 'ten']

# %%
for i in list1:
    print(i)
# Out:
# one
# two
# three
# four
# five
# six
# seven
# eight
# nine
# ten

# %%
for i in enumerate(list1):
    print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')
# (6, 'seven')
# (7, 'eight')
# (8, 'nine')
# (9, 'ten')

# %% [markdown]
# # Count

# %%
list1.count('one')
# Out:
# 1

# %%
list10 =['one', 'two', 'three', 'four', 'one', 'one', 'two', 'three'] 
list10
# Out:
# ['one', 'two', 'three', 'four', 'one', 'one', 'two', 'three']

# %%
list10.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 list10.count()
#
# TypeError: list.count() takes exactly one argument (0 given)

# %%
list10.count('one')
# Out:
# 3

# %%
list10.index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 list10.index()
#
# TypeError: index expected at least 1 argument, got 0

# %%
list10.index(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[120], line 1
# ----> 1 list10.index(0)
#
# ValueError: 0 is not in list

# %%
list10.index('one')
# Out:
# 0

# %%
list10.clear()

# %%
list10
# Out:
# []

# %%
del list10

# %%
list10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 list10
#
# NameError: name 'list10' is not defined

# %% [markdown]
# # All / Any
#
# The all() method returns:
#
# True - If all elements in a list are true
#
# False - If any element in a list is false
#
# The any() function returns True if any element in the list is True. If not, any() returns False.

# %%
L1 = [1,2,3,4,0]

# %%
all(L1) # Will Return false as one value is false (Value 0)
# Out:
# False

# %%
any(L1) # Will Return True as we have items in the list with True value
# Out:
# True

# %%
L2 = [1,2,3,4,True,False] 
L2
# Out:
# [1, 2, 3, 4, True, False]

# %%
all(L2)  # Returns false as one value is false
# Out:
# False

# %%
any(L2)  # Will Return True as we have items in the list with True value
# Out:
# True

# %%
L3 = [1,2,3,True] 
L3
# Out:
# [1, 2, 3, True]

# %%
all(L3) # Will return True as all items in the list are True
# Out:
# True

# %% [markdown]
# # Tuple

# %% [markdown]
# # Tuple Creation

# %%
tuple1 = ()
tuple1
# Out:
# ()

# %%
tuple2 = ( 2, 5 ,7)
tuple2
# Out:
# (2, 5, 7)

# %%
tuple3 =( 2.4,3.1,3.3)

# %%
tuple3
# Out:
# (2.4, 3.1, 3.3)

# %%
tuple4 = ('Mohan', 'is', 'from', 'India')
tuple4
# Out:
# ('Mohan', 'is', 'from', 'India')

# %%
tuple5 =(1,2,3,'Mohan',5.5,2+3j)
tuple5
# Out:
# (1, 2, 3, 'Mohan', 5.5, (2+3j))

# %%
tuple6 = (5,6,7,(3,2),(11,4))
tuple6
# Out:
# (5, 6, 7, (3, 2), (11, 4))

# %%
len(tuple5)
# Out:
# 6

# %%
len(tuple6)
# Out:
# 5

# %% [markdown]
# # Tuple Indexing

# %%
tuple1
# Out:
# ()

# %%
tuple5[0]
# Out:
# 1

# %%
tuple5
# Out:
# (1, 2, 3, 'Mohan', 5.5, (2+3j))

# %%
tuple5[5]
# Out:
# (2+3j)

# %%
tuple4
# Out:
# ('Mohan', 'is', 'from', 'India')

# %%
tuple4[::-1]
# Out:
# ('India', 'from', 'is', 'Mohan')

# %% [markdown]
#  # Tuple Slicing

# %%
mytuple = ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
mytuple[:]
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
mytuple[3:]
# Out:
# ('four', 'five', 'six', 'seven', 'eight')

# %%
mytuple[-1]
# Out:
# 'eight'

# %%
mytuple[::-1]
# Out:
# ('eight', 'seven', 'six', 'five', 'four', 'three', 'two', 'one')

# %% [markdown]
# # Remove and change items in tuple

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
del mytuple[0] #TypeError: 'tuple' object doesn't support item deletion
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[171], line 1
# ----> 1 del mytuple[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
mytuple[0] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[172], line 1
# ----> 1 mytuple[0] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
mytuple1 = mytuple.copy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[174], line 1
# ----> 1 mytuple1 = mytuple.copy()
#
# AttributeError: 'tuple' object has no attribute 'copy'

# %%
mytuple.count('one') #The count() method tells you how many times a value appears in a tuple.
# Out:
# 1

# %%
mytuple.count(5)
# Out:
# 0

# %%
del mytuple

# %%
mytuple
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[183], line 1
# ----> 1 mytuple
#
# NameError: name 'mytuple' is not defined

# %%
mytuple = ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
for i in mytuple:
    print(i)
# Out:
# one
# two
# three
# four
# five
# six
# seven
# eight

# %%
for i in enumerate(mytuple):
    print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')
# (6, 'seven')
# (7, 'eight')

# %% [markdown]
# # Tuple Membershi

# %%
'one' in mytuple
# Out:
# True

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
'ten' in mytuple
# Out:
# False

# %% [markdown]
# # Index position

# %%
mytuple.index('three')
# Out:
# 2

# %%
mytuple.index('Ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[193], line 1
# ----> 1 mytuple.index('Ten')
#
# ValueError: tuple.index(x): x not in tuple

# %% [markdown]
# # sorting

# %%
mytuple1= (3,2,5,4,7,9,1)
mytuple1
# Out:
# (3, 2, 5, 4, 7, 9, 1)

# %%
sort.mytuple1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[195], line 1
# ----> 1 sort.mytuple1
#
# NameError: name 'sort' is not defined

# %%
sorted(mytuple1)
# Out:
# [1, 2, 3, 4, 5, 7, 9]
