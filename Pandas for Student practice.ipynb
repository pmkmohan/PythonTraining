# %%
# %pip install openpyxl ( install if any error occur on excel file)
# HAve the required data file in CSV or Excell

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
df = pd.read_excel(r'C:\Users\patharapilli\OneDrive - adesso Group\Documents\Mohan.P\learnings\NarashIT\JunBatch\21st_Jul_Pandas\data.xlsx')

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]

# %%
len(df)
# Out:
# 195

# %%
df.shape
# Out:
# (195, 5)

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,4]

# %%
x
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
# [195 rows x 4 columns]

# %%
y
# Out:
# 0              High income
# 1               Low income
# 2      Upper middle income
# 3      Upper middle income
# 4              High income
#               ...
# 190    Lower middle income
# 191    Upper middle income
# 192             Low income
# 193    Lower middle income
# 194             Low income
# Name: IncomeGroup, Length: 195, dtype: object

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 5

# %%
df.isnull()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
df.isnull()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
df.isna()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
df.shape
# Out:
# (195, 5)

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()  # print top 5 rows (0 to 4 rows)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.head(20) # gives the data from 0 to 19 records
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 0                    Aruba         ABW     10.244       78.90000
# 1              Afghanistan         AFG     35.253        5.90000
# 2                   Angola         AGO     45.985       19.10000
# 3                  Albania         ALB     12.877       57.20000
# 4     United Arab Emirates         ARE     11.044       88.00000
# 5                Argentina         ARG     17.716       59.90000
# 6                  Armenia         ARM     13.308       41.90000
# 7      Antigua and Barbuda         ATG     16.447       63.40000
# 8                Australia         AUS     13.200       83.00000
# 9                  Austria         AUT      9.400       80.61880
# 10              Azerbaijan         AZE     18.300       58.70000
# 11                 Burundi         BDI     44.151        1.30000
# 12                 Belgium         BEL     11.200       82.17020
# 13                   Benin         BEN     36.440        4.90000
# 14            Burkina Faso         BFA     40.551        9.10000
# 15              Bangladesh         BGD     20.142        6.63000
# 16                Bulgaria         BGR      9.200       53.06150
# 17                 Bahrain         BHR     15.040       90.00004
# 18            Bahamas, The         BHS     15.339       72.00000
# 19  Bosnia and Herzegovina         BIH      9.062       57.79000
#
#             IncomeGroup
# 0           High income
# 1            Low income
# 2   Upper middle income
# 3   Upper middle income
# 4           High income
# 5           High income
# 6   Lower middle income
# 7           High income
# 8           High income
# 9           High income
# 10  Upper middle income
# 11           Low income
# 12          High income
# 13           Low income
# 14           Low income
# 15  Lower middle income
# 16  Upper middle income
# 17          High income
# 18          High income
# 19  Upper middle income

# %%
df.tail() # gives the last 5 records
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %% [markdown]
# # Second day class on Pandas advance (22/07/2026)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df[:]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]

# %%
df[:10] # it gives dataframe, ie starts from 0 record to (n-1) ie (10-1)=9 records
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244        78.9000
# 1           Afghanistan         AFG     35.253         5.9000
# 2                Angola         AGO     45.985        19.1000
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
df[10:20] # it will give records from 10 till 20th one (20-1) 19th recored
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 10              Azerbaijan         AZE     18.300       58.70000
# 11                 Burundi         BDI     44.151        1.30000
# 12                 Belgium         BEL     11.200       82.17020
# 13                   Benin         BEN     36.440        4.90000
# 14            Burkina Faso         BFA     40.551        9.10000
# 15              Bangladesh         BGD     20.142        6.63000
# 16                Bulgaria         BGR      9.200       53.06150
# 17                 Bahrain         BHR     15.040       90.00004
# 18            Bahamas, The         BHS     15.339       72.00000
# 19  Bosnia and Herzegovina         BIH      9.062       57.79000
#
#             IncomeGroup
# 10  Upper middle income
# 11           Low income
# 12          High income
# 13           Low income
# 14           Low income
# 15  Lower middle income
# 16  Upper middle income
# 17          High income
# 18          High income
# 19  Upper middle income

# %%
df[::10] # it gives record of every 10th place
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0          Aruba         ABW     10.244      78.900000          High income
# 10    Azerbaijan         AZE     18.300      58.700000  Upper middle income
# 20       Belarus         BLR     12.500      54.170000  Upper middle income
# 30        Canada         CAN     10.900      85.800000          High income
# 40    Costa Rica         CRI     15.022      45.960000  Upper middle income
# 50       Ecuador         ECU     21.070      40.353684  Upper middle income
# 60         Gabon         GAB     30.555       9.200000  Upper middle income
# 70     Greenland         GRL     14.500      65.800000          High income
# 80         India         IND     20.291      15.100000  Lower middle income
# 90    Kazakhstan         KAZ     22.730      54.000000  Upper middle income
# 100        Libya         LBY     21.425      16.500000  Upper middle income
# 110      Moldova         MDA     12.141      45.000000  Lower middle income
# 120   Mozambique         MOZ     39.705       5.400000           Low income
# 130  Netherlands         NLD     10.200      93.956400          High income
# 140       Poland         POL      9.600      62.849200          High income
# 150        Sudan         SDN     33.477      22.700000  Lower middle income
# 160     Suriname         SUR     18.455      37.400000  Upper middle income
# 170   Tajikistan         TJK     30.792      16.000000  Lower middle income
# 180      Uruguay         URY     14.374      57.690000          High income
# 190  Yemen, Rep.         YEM     32.947      20.000000  Lower middle income

# %%
df.info
# Out:
# <bound method DataFrame.info of               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]>

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df['BirthRate']
# Out:
# 0      10.244
# 1      35.253
# 2      45.985
# 3      12.877
# 4      11.044
#         ...
# 190    32.947
# 191    20.850
# 192    42.394
# 193    40.471
# 194    35.715
# Name: BirthRate, Length: 195, dtype: float64

# %%
df[['BirthRate','InternetUsers']]
# Out:
#      BirthRate  InternetUsers
# 0       10.244           78.9
# 1       35.253            5.9
# 2       45.985           19.1
# 3       12.877           57.2
# 4       11.044           88.0
# ..         ...            ...
# 190     32.947           20.0
# 191     20.850           46.5
# 192     42.394            2.2
# 193     40.471           15.4
# 194     35.715           18.5
#
# [195 rows x 2 columns]

# %% [markdown]
# # Pandas Brackets: When to Use Which One?
#     Pandas uses normal Python syntax. The main symbols you will use are:
#     Symbol	Common purpose
#     ()	     Call a function or method; pass arguments
#     []	     Select data, index data, or slice data
#     :	     Specify a range/slice inside []
#     {}	     Create dictionaries or sets
#     .	     Access a method or attribute

# %%
df.sort_values('BirthRate')
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 142              Portugal         PRT      7.900        62.0956
# 74   Hong Kong SAR, China         HKG      7.900        74.2000
# 89                  Japan         JPN      8.200        89.7100
# 68                 Greece         GRC      8.500        59.8663
# 45                Germany         DEU      8.500        84.1700
# ..                    ...         ...        ...            ...
# 115                  Mali         MLI     44.138         3.5000
# 11                Burundi         BDI     44.151         1.3000
# 167                  Chad         TCD     45.745         2.3000
# 2                  Angola         AGO     45.985        19.1000
# 127                 Niger         NER     49.661         1.7000
#
#              IncomeGroup
# 142          High income
# 74           High income
# 89           High income
# 68           High income
# 45           High income
# ..                   ...
# 115           Low income
# 11            Low income
# 167           Low income
# 2    Upper middle income
# 127           Low income
#
# [195 rows x 5 columns]

# %%
df.head
# Out:
# <bound method NDFrame.head of               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]>

# %%
df.head[3]  # Note df.head() is method and we need to use() brackets and not []
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df.head[3]  # Note df.head() is method and we need to use() brackets and not []
#
# TypeError: 'method' object is not subscriptable

# %%
df.head(3) # Note head() method takes argument in it as 3 here and give the 3 records. from 0 to 2
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0        Aruba         ABW     10.244           78.9          High income
# 1  Afghanistan         AFG     35.253            5.9           Low income
# 2       Angola         AGO     45.985           19.1  Upper middle income

# %%
df['BirthRate'] # it give the recordd of BirthRate. only one column data we can use df[]
# Out:
# 0      10.244
# 1      35.253
# 2      45.985
# 3      12.877
# 4      11.044
#         ...
# 190    32.947
# 191    20.850
# 192    42.394
# 193    40.471
# 194    35.715
# Name: BirthRate, Length: 195, dtype: float64

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df[['BirthRate', 'InternetUsers']] # if we want multiple columns df[[1,2]]
                                        #The outer [] selects data from the DataFrame.
                                        #The inner [] creates a Python list of column names.
# Out:
#      BirthRate  InternetUsers
# 0       10.244           78.9
# 1       35.253            5.9
# 2       45.985           19.1
# 3       12.877           57.2
# 4       11.044           88.0
# ..         ...            ...
# 190     32.947           20.0
# 191     20.850           46.5
# 192     42.394            2.2
# 193     40.471           15.4
# 194     35.715           18.5
#
# [195 rows x 2 columns]

# %% [markdown]
# # split the dataset into numerical dataframes & categorical dataframe

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
df_num = df[['BirthRate', 'InternetUsers']]
df_num
# Out:
#      BirthRate  InternetUsers
# 0       10.244           78.9
# 1       35.253            5.9
# 2       45.985           19.1
# 3       12.877           57.2
# 4       11.044           88.0
# ..         ...            ...
# 190     32.947           20.0
# 191     20.850           46.5
# 192     42.394            2.2
# 193     40.471           15.4
# 194     35.715           18.5
#
# [195 rows x 2 columns]

# %%
df_cat = df[['CountryName', 'CountryCode','IncomeGroup']]
df_cat
# Out:
#               CountryName CountryCode          IncomeGroup
# 0                   Aruba         ABW          High income
# 1             Afghanistan         AFG           Low income
# 2                  Angola         AGO  Upper middle income
# 3                 Albania         ALB  Upper middle income
# 4    United Arab Emirates         ARE          High income
# ..                    ...         ...                  ...
# 190           Yemen, Rep.         YEM  Lower middle income
# 191          South Africa         ZAF  Upper middle income
# 192      Congo, Dem. Rep.         COD           Low income
# 193                Zambia         ZMB  Lower middle income
# 194              Zimbabwe         ZWE           Low income
#
# [195 rows x 3 columns]

# %%
df_num , df_cat
# Out:
# (     BirthRate  InternetUsers
#  0       10.244           78.9
#  1       35.253            5.9
#  2       45.985           19.1
#  3       12.877           57.2
#  4       11.044           88.0
#  ..         ...            ...
#  190     32.947           20.0
#  191     20.850           46.5
#  192     42.394            2.2
#  193     40.471           15.4
#  194     35.715           18.5
#
#  [195 rows x 2 columns],
#                CountryName CountryCode          IncomeGroup
#  0                   Aruba         ABW          High income
#  1             Afghanistan         AFG           Low income
#  2                  Angola         AGO  Upper middle income
#  3                 Albania         ALB  Upper middle income
#  4    United Arab Emirates         ARE          High income
#  ..                    ...         ...                  ...
#  190           Yemen, Rep.         YEM  Lower middle income
#  191          South Africa         ZAF  Upper middle income
#  192      Congo, Dem. Rep.         COD           Low income
#  193                Zambia         ZMB  Lower middle income
#  194              Zimbabwe         ZWE           Low income
#
#  [195 rows x 3 columns])

# %%
df_num.head(2)
# Out:
#    BirthRate  InternetUsers
# 0     10.244           78.9
# 1     35.253            5.9

# %%
df_cat.head(2)
# Out:
#    CountryName CountryCode  IncomeGroup
# 0        Aruba         ABW  High income
# 1  Afghanistan         AFG   Low income

# %%
print(df_num.columns)
print(df_cat.columns)
# Out:
# Index(['BirthRate', 'InternetUsers'], dtype='object')
# Index(['CountryName', 'CountryCode', 'IncomeGroup'], dtype='object')

# %%
print(df_num.isna().sum())
print(df_cat.isna().sum())
# Out:
# BirthRate        0
# InternetUsers    0
# dtype: int64
# CountryName    0
# CountryCode    0
# IncomeGroup    0
# dtype: int64

# %%
df_num.count()
# Out:
# BirthRate        195
# InternetUsers    195
# dtype: int64

# %%
df.describe()
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
df_num.describe()
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
df_cat
# Out:
#               CountryName CountryCode          IncomeGroup
# 0                   Aruba         ABW          High income
# 1             Afghanistan         AFG           Low income
# 2                  Angola         AGO  Upper middle income
# 3                 Albania         ALB  Upper middle income
# 4    United Arab Emirates         ARE          High income
# ..                    ...         ...                  ...
# 190           Yemen, Rep.         YEM  Lower middle income
# 191          South Africa         ZAF  Upper middle income
# 192      Congo, Dem. Rep.         COD           Low income
# 193                Zambia         ZMB  Lower middle income
# 194              Zimbabwe         ZWE           Low income
#
# [195 rows x 3 columns]

# %%
df_cat.describe()
# Out:
#        CountryName CountryCode  IncomeGroup
# count          195         195          195
# unique         195         195            4
# top          Aruba         ABW  High income
# freq             1           1           67

# %% [markdown]
# # how to change the column names

# %%
df.columns = ['a','b','c','d','e']

# %%
df.head(2)
# Out:
#              a    b       c     d            e
# 0        Aruba  ABW  10.244  78.9  High income
# 1  Afghanistan  AFG  35.253   5.9   Low income

# %% [markdown]
# # Change back to original coulmns

# %%
df.columns = ['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers', 'IncomeGroup']

# %%
df.head(2)
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0        Aruba         ABW     10.244           78.9  High income
# 1  Afghanistan         AFG     35.253            5.9   Low income

# %%
df.BirthRate * df.InternetUsers
# Out:
# 0      808.2516
# 1      207.9927
# 2      878.3135
# 3      736.5644
# 4      971.8720
#          ...
# 190    658.9400
# 191    969.5250
# 192     93.2668
# 193    623.2534
# 194    660.7275
# Length: 195, dtype: float64

# %%
df['myCalc'] = df.BirthRate * df.InternetUsers

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup    myCalc
# 0            High income  808.2516
# 1             Low income  207.9927
# 2    Upper middle income  878.3135
# 3    Upper middle income  736.5644
# 4            High income  971.8720
# ..                   ...       ...
# 190  Lower middle income  658.9400
# 191  Upper middle income  969.5250
# 192           Low income   93.2668
# 193  Lower middle income  623.2534
# 194           Low income  660.7275
#
# [195 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup', 'myCalc'],
#       dtype='object')

# %%
id(df)
# Out:
# 2165031924272

# %%
df =df.drop('myCalc') #it need axies that is why we are gettin error df =df.drop('myCalc', axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 df =df.drop('myCalc')
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['myCalc'] not found in axis"

# %%
df =df.drop('myCalc', axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 df =df.drop('myCalc', axis = 1)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['myCalc'] not found in axis"

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]

# %% [markdown]
# # Filter in dataframe

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]

# %%
df['InternetUsers'] <20
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193     True
# 194     True
# Name: InternetUsers, Length: 195, dtype: bool

# %%
df[df['InternetUsers'] <20]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 1         Afghanistan         AFG     35.253            5.9
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 13              Benin         BEN     36.440            4.9
# 14       Burkina Faso         BFA     40.551            9.1
# ..                ...         ...        ...            ...
# 187           Vanuatu         VUT     26.739           11.3
# 189             Samoa         WSM     26.172           15.3
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 1             Low income
# 2    Upper middle income
# 11            Low income
# 13            Low income
# 14            Low income
# ..                   ...
# 187  Lower middle income
# 189  Lower middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [64 rows x 5 columns]

# %%
# df[df['InternetUsers'] <20 & df['BirthRate'] >30]
df[(df.InternetUsers <3 ) & (df.BirthRate >40)]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11            Burundi         BDI     44.151            1.3  Low income
# 127             Niger         NER     49.661            1.7  Low income
# 156           Somalia         SOM     43.891            1.5  Low income
# 167              Chad         TCD     45.745            2.3  Low income
# 192  Congo, Dem. Rep.         COD     42.394            2.2  Low income

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
#
# [195 rows x 5 columns]

# %%
df.IncomeGroup == 'Lower middle income'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190     True
# 191    False
# 192    False
# 193     True
# 194    False
# Name: IncomeGroup, Length: 195, dtype: bool

# %%
df[df.IncomeGroup == 'Lower middle income']
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 6                  Armenia         ARM     13.308        41.9000
# 15              Bangladesh         BGD     20.142         6.6300
# 23                 Bolivia         BOL     24.236        36.9400
# 27                  Bhutan         BTN     18.134        29.9000
# 34           Cote d'Ivoire         CIV     37.320         8.4000
# 35                Cameroon         CMR     37.236         6.4000
# 36             Congo, Rep.         COG     37.011         6.6000
# 39              Cabo Verde         CPV     21.625        37.5000
# 46                Djibouti         DJI     25.486         9.5000
# 51        Egypt, Arab Rep.         EGY     28.032        29.4000
# 59   Micronesia, Fed. Sts.         FSM     23.511        27.8000
# 62                 Georgia         GEO     13.332        43.3000
# 63                   Ghana         GHA     33.131        12.3000
# 71               Guatemala         GTM     27.465        19.7000
# 73                  Guyana         GUY     18.885        35.0000
# 75                Honduras         HND     21.593        17.8000
# 79               Indonesia         IDN     20.297        14.9400
# 80                   India         IND     20.291        15.1000
# 91                   Kenya         KEN     35.194        39.0000
# 92         Kyrgyz Republic         KGZ     27.200        23.0000
# 94                Kiribati         KIR     29.044        11.5000
# 97                 Lao PDR         LAO     27.051        12.5000
# 103              Sri Lanka         LKA     17.863        21.9000
# 104                Lesotho         LSO     28.738         5.0000
# 109                Morocco         MAR     21.023        56.0000
# 110                Moldova         MDA     12.141        45.0000
# 117                Myanmar         MMR     18.119         1.6000
# 121             Mauritania         MRT     33.801         6.2000
# 128                Nigeria         NGA     40.045        38.0000
# 129              Nicaragua         NIC     20.788        15.5000
# 135               Pakistan         PAK     29.582        10.9000
# 138            Philippines         PHL     23.790        37.0000
# 139       Papua New Guinea         PNG     28.899         6.5000
# 150                  Sudan         SDN     33.477        22.7000
# 151                Senegal         SEN     38.533        13.1000
# 153        Solomon Islands         SLB     30.578         8.0000
# 155            El Salvador         SLV     17.476        23.1093
# 159  Sao Tome and Principe         STP     34.537        23.0000
# 164              Swaziland         SWZ     30.093        24.7000
# 166   Syrian Arab Republic         SYR     24.043        26.2000
# 170             Tajikistan         TJK     30.792        16.0000
# 172            Timor-Leste         TLS     35.755         1.1000
# 179                Ukraine         UKR     11.100        41.0000
# 182             Uzbekistan         UZB     22.500        38.2000
# 186                Vietnam         VNM     15.537        43.9000
# 187                Vanuatu         VUT     26.739        11.3000
# 188     West Bank and Gaza         PSE     30.394        46.6000
# 189                  Samoa         WSM     26.172        15.3000
# 190            Yemen, Rep.         YEM     32.947        20.0000
# 193                 Zambia         ZMB     40.471        15.4000
#
#              IncomeGroup
# 6    Lower middle income
# 15   Lower middle income
# 23   Lower middle income
# 27   Lower middle income
# 34   Lower middle income
# 35   Lower middle income
# 36   Lower middle income
# 39   Lower middle income
# 46   Lower middle income
# 51   Lower middle income
# 59   Lower middle income
# 62   Lower middle income
# 63   Lower middle income
# 71   Lower middle income
# 73   Lower middle income
# 75   Lower middle income
# 79   Lower middle income
# 80   Lower middle income
# 91   Lower middle income
# 92   Lower middle income
# 94   Lower middle income
# 97   Lower middle income
# 103  Lower middle income
# 104  Lower middle income
# 109  Lower middle income
# 110  Lower middle income
# 117  Lower middle income
# 121  Lower middle income
# 128  Lower middle income
# 129  Lower middle income
# 135  Lower middle income
# 138  Lower middle income
# 139  Lower middle income
# 150  Lower middle income
# 151  Lower middle income
# 153  Lower middle income
# 155  Lower middle income
# 159  Lower middle income
# 164  Lower middle income
# 166  Lower middle income
# 170  Lower middle income
# 172  Lower middle income
# 179  Lower middle income
# 182  Lower middle income
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 193  Lower middle income

# %%
len(df[df.IncomeGroup == 'Lower middle income'])
# Out:
# 50

# %% [markdown]
# # visualizatioin concepts - on 23rd Jun class

# %% [markdown]
#         Overview of Python Visualization Tools
# Python is the preferred language of choice for data scientists. Python have multiple options for data visualization. It has several tools which can help us to visualize the data more effectively. These Python data visualization tools are as follows:-
#
# • Matplotlib
#
# • Seaborn
#
# • pandas
#
# • Bokeh
#
# • Plotly - R PROGRAMING PACKAGE
#
# • ggplot - R PROGRAMING PACKAGE
#
# • pygal - R programing pacakge
#
# In the following sections, I discuss Matplotlib as the data visualization tool.

# %%
import pandas as pd  # for Dataframes
import matplotlib.pyplot as plt # for Visualization
import seaborn as sns #  statistical visualization ( distribution plto, )

# %%
# %matplotlib inline # KEEP THE GRAPH PROPER SHAPE 
plt.rcParams['figure.figsize'] = 6,2 # height & width of the graph
# Out:
# UsageError: unrecognized arguments: # KEEP THE GRAPH PROPER SHAPE

# %%
import warnings    # ignore the warning message which cause by system / os updateion 
warnings.filterwarnings('ignore')

# %% [markdown]
#     # Matplotlib is the basic plotting library of Python programming language. It is the most prominent tool among Python visualization packages. Matplotlib is highly efficient in performing wide range of tasks. It can produce publication quality figures in a variety of formats. It can export visualizations to all of the common formats like PDF, SVG, JPG, PNG, BMP and GIF. It can create popular visualization types – line plot, scatter plot, histogram, bar chart, error charts, pie chart, box plot, and many more types of plot. Matplotlib also supports 3D plotting. Many Python libraries are built on top of Matplotlib. For example, pandas and Seaborn are built on Matplotlib. They allow to access Matplotlib’s methods with less code.

# %% [markdown]
#         #Plotting from a Jupyter notebook
# The Jupyter Notebook (formerly known as the IPython Notebook) is a data analysis and visualization tool that provides multiple tools under one roof. It provides code execution, graphical plots, rich text and media display, mathematics formula and much more facilities into a single executable document.
#
# Interactive plotting within a Jupyter Notebook can be done with the %matplotlib command. There are two possible options to work with graphics in Jupyter Notebook. These are as follows:-
#
# • %matplotlib notebook – This command will produce interactive plots embedded within the notebook.
#
# • %matplotlib inline – It will output static images of the plot embedded in the notebook.
#
# After this command (it needs to be done only once per kernel per session), any cell within the notebook that creates a plot will embed a PNG image of the graphic.

# %%
df.head(1)
# Out:
#   CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0       Aruba         ABW     10.244           78.9  High income

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df['InternetUsers']
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
vis1 = sns.distplot(df['InternetUsers'])  # univariate analysis

# %%
vis2 = sns.displot(df['InternetUsers'])

# %%
vis3 = sns.distplot(df['InternetUsers'],bins= 15)

# %%
vis4 = sns.boxplot(data= df, x='IncomeGroup', y='BirthRate')

# %%
vis5 = sns.lmplot(data =df ,x= 'InternetUsers',y= 'BirthRate')

# %%
vis6 = sns.lmplot(data =df, x ='InternetUsers',y= 'BirthRate',fit_reg= False)

# %%
vis7 = sns.lmplot(data =df, x ='InternetUsers',y= 'BirthRate',fit_reg= False, hue= 'IncomeGroup')

# %%
import numpy as np

# %matplotlib inline
x1 = np.linspace(0, 10, 50)

# create a plot figure
#fig = plt.figure()

plt.plot(x1, np.sin(x1), '-')
plt.plot(x1, np.cos(x1), '--')
#plt.plot(x1, np.tan(x1), '--')

# %%
# create the first of two panels and set current axis
plt.subplot(2, 1, 1)   # (rows, columns, panel number)
plt.plot(x1, np.cos(x1), '*')

# %%
# create a plot figure
plt.figure()


# create the first of two panels and set current axis
plt.subplot(2, 1, 1)   # (rows, columns, panel number)
plt.plot(x1, np.sin(x1))

# create the second of two panels and set current axis
plt.subplot(2, 1, 2)   # (rows, columns, panel number)
plt.plot(x1, np.cos(x1));

# %%
# get current figure information

print(plt.gcf())
# Out:
# Figure(640x480)

# %%
# get current axis information

print(plt.gca())
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
#     #Visualization with Pyplot
# Generating visualization with Pyplot is very easy. The x-axis values ranges from 0-3 and the y-axis from 1-4. If we provide a single list or array to the plot() command, matplotlib assumes it is a sequence of y values, and automatically generates the x values. Since python ranges start with 0, the default x vector has the same length as y but starts with 0. Hence the x data are [0,1,2,3] and y data are [1,2,3,4].

# %%
plt.plot([1,2,3,4], [1,8,2,16])
plt.ylabel('Numbers')
#plt.show()
# Out:
# Text(0, 0.5, 'Numbers')

# %% [markdown]
#  plot() - A versatile command
# plot() is a versatile command. It will take an arbitrary number of arguments. For example, to plot x versus y, we can issue the following command:-

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4], [1, 8, 27, 64])

# %%
x = np.linspace(0,2,100)

plt.plot( x,x, label = 'linear')
plt.plot( x, x**2, label = 'quadratic')
plt.plot(x, x**3, label = 'cubic')

plt.xlabel('x axies')
plt.ylabel('y axies')

plt.title("Simple plot")
plt.legend()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro') # Formatting the style of plot
plt.axis([0, 6, 0, 20]) 
# The axis() command in the example above takes a list of [xmin, xmax, ymin, ymax] and specifies the viewport of the axes.
# Out:
# (np.float64(0.0), np.float64(6.0), np.float64(0.0), np.float64(20.0))

# %% [markdown]
# Working with NumPy arrays
# Generally, we have to work with NumPy arrays. All sequences are converted to numpy arrays internally. The below example illustrates plotting several lines with different format styles in one command using arrays

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# 14. Saving the Plot
# We can save the figures in a wide variety of formats. We can save them using the savefig() command as follows:-
#
# fig.savefig(‘fig1.png’)
#
# We can explore the contents of the file using the IPython Image object.
#
# from IPython.display import Image
#
# Image(‘fig1.png’)
#
# In savefig() command, the file format is inferred from the extension of the given filename. Depending on the backend, many different file formats are available. The list of supported file types can be found by using the get_supported_filetypes() method of the figure canvas object as follows:-
#
# fig.canvas.get_supported_filetypes()

# %%
fig = plt.figure()

x2 = np.linspace(0, 5, 10)
y2 = x2 ** 2

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])

axes.plot(x2, y2, 'r')

axes.set_xlabel('x2')
axes.set_ylabel('y2')
axes.set_title('title');

# %%
# Saving the figure

fig.savefig('plot1.png')

# %%
# Explore the contents of figure

from IPython.display import Image

Image('plot1.png')

# %%
# Explore supported file formats


fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format',
#  'webp': 'WebP Image Format'}

# %% [markdown]
# Histogram
# Histogram charts are a graphical display of frequencies. They are represented as bars. They show what portion of the dataset falls into each category, usually specified as non-overlapping intervals. These categories are called bins.
#
# The plt.hist() function can be used to plot a simple histogram as follows:-

# %%
data1 = np.random.randn(1000)

plt.hist(data1);

# %%
#vis01 = hist(df['InternetUsers'])
plt.hist(df['InternetUsers']);

# %%
data2 = [5. , 25. , 50. , 20.]

plt.barh(range(len(data2)), data2)

plt.show()

# %% [markdown]
# Pie Chart
# Pie charts are circular representations, divided into sectors. The sectors are also called wedges. The arc length of each sector is proportional to the quantity we are describing. It is an effective way to represent information when we are interested mainly in comparing the wedge against the whole pie, instead of wedges against each other.
#
# Matplotlib provides the pie() function to plot pie charts from an array X. Wedges are created proportionally, so that each value x of array X generates a wedge proportional to x/sum(X).

# %%
plt.figure(figsize=(7,7))

x10 = [35, 25, 20, 20]

labels = ['Computer', 'Electronics', 'Mechanical', 'Chemical']

plt.pie(x10, labels=labels);

plt.show()

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
# Create a matrix
matrix1 = np.random.rand(10, 20)

cp = plt.contour(matrix1)

plt.show()
