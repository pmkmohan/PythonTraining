# %% [markdown]
# # Print is used for answer

# %%
a=10
b=20
a,b
# Out:
# (10, 20)

# %%
print (a, b)
# Out:
# 10 20

# %%
print(10)
print(10,20)
print('Python')
print(10,20,"Python")
# Out:
# 10
# 10 20
# Python
# 10 20 Python

# %%
num1= 20
num2=30
add = num1+num2
print(add)
# Out:
# 50

# %% [markdown]
# # Print results with strings

# %%
print('The addition of', num1,',', num2, 'is', add)
# Out:
# The addition of 20 , 30 is 50

# %%
name = 'python'
age = 20
city = 'hyd'

# %%
print('My name is',name , 'and my age is',age,'and i live in',city)
# Out:
# My name is python and my age is 20 and i live in hyd

# %% [markdown]
# # Print format method

# %%
num1=20;
num2=30;
sum = num1+num2
print('The Addition of {} and {} is = {}'.format(num1,num2,sum))
# Out:
# The Addition of 20 and 30 is = 50

# %%
name = 'python'
age = 20
city = 'hyd'
print(' Hi, My name is {} , my age is {} and i live in {}'.format(name, age,city))
# Out:
#  Hi, My name is python , my age is 20 and i live in hyd

# %%
num1=100 
num2=25 
num3=333 
avg = ((num1+num2+num3)/3)
avg1 = round((num1+num2+num3)/3,2)
avg, avg1
# Out:
# (152.66666666666666, 152.67)

# %%
print( 'The average of {},{} and {} is {} and round off up to 2 decimels is {}'.format(num1,num2,num3,avg,avg1))
# Out:
# The average of 100,25 and 333 is 152.66666666666666 and round off up to 2 decimels is 152.67

# %% [markdown]
# # More short format method(f string method)
#
# variable should be in curly braces
# and write everything inside quots ''
# at starting simpaly add f

# %%
num1=100 
num2=25 
num3=333 
avg = ((num1+num2+num3)/3)
avg1 = round((num1+num2+num3)/3,2)
print(f'The average of {num1},{num2} and {num3} is with round off till two decimels is {avg1}.')
# Out:
# The average of 100,25 and 333 is with round off till two decimels is 152.67.

# %% [markdown]
# # end Statement

# %%
print('hello')
print('Good morning')
# Out:
# hello
# Good morning

# %%
print('hello ',end='') # Here we will use end statement that joint line from end of one string to starting of other 
                        #string 
print('Good morning')
# Out:
# hello Good morning

# %% [markdown]
# # seprator
#
# here one print statement only we use
#
# insisde one print statement we have multipal values
#
# we want to seperate these multipal values with anything

# %%
print('hello','hi','how are you',sep ='--->')
# Out:
# hello--->hi--->how are you

# %%
print('hello','hi','how are you',sep ='$$$')
# Out:
# hello$$$hi$$$how are you

# %% [markdown]
# # Python Type Casting

# %%
i = int(2.3)
print(i)
print(type(i))
# Out:
# 2
# <class 'int'>

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(1+2J)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 int(1+2J)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('Mohan')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 int('Mohan')
#
# ValueError: invalid literal for int() with base 10: 'Mohan'

# %%
float(2)
# Out:
# 2.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float(2+3j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 float(2+3j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float(None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 float(None)
#
# TypeError: float() argument must be a string or a real number, not 'NoneType'

# %%
float('10')
# Out:
# 10.0

# %% [markdown]
# # All other datatype to bool

# %%
bool(1)
# Out:
# True

# %%
bool(5)
# Out:
# True

# %%
bool(-1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(a+2j)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 bool(a+2j)
#
# NameError: name 'a' is not defined

# %%
bool(2+3j)
# Out:
# True

# %% [markdown]
# # All other dataype complex

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(-2,3)
# Out:
# (-2+3j)

# %%
Complex(true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 Complex(true)
#
# NameError: name 'Complex' is not defined

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(True,False)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 complex(10,20,30)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex('a')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 complex('a')
#
# ValueError: complex() arg is a malformed string

# %%
complex('1')
# Out:
# (1+0j)

# %%
str(20)
# Out:
# '20'

# %%
str(True)
# Out:
# 'True'

# %%
str(2+3j)
# Out:
# '(2+3j)'
