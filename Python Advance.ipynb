# %%
i =45
i
# Out:
# 45

# %%
type(i)
# Out:
# int

# %%
f=102.4
f
# Out:
# 102.4

# %%
type(f)
# Out:
# float

# %%
b= True
b
# Out:
# True

# %%
type(b)
# Out:
# bool

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
print(True+True)
# Out:
# 2

# %% [markdown]
# # import math module
# https://docs.python.org/3/library/math.html

# %%
import math as m

# %% [markdown]
# m.add(2,3)

# %%
x = m.sqrt(25)
x
# Out:
# 5.0

# %%
print(int(float(2.5)))
# Out:
# 2

# %%
print(m.floor(8.5))
# Out:
# 8

# %%
print(m.ceil(8.5))
# Out:
# 9

# %%
print(m.pow(2,3))
# Out:
# 8.0

# %%
print(m.acos(2.5))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print(m.acos(2.5))
#
# ValueError: math domain error

# %%
x1 = int(input(" Enter the first value"))
x2 = int(input(" Enter the second Value"))
print(x1+x2)
# Out:
#  Enter the first value 25
#  Enter the second Value 32
# 57

# %%
ch = input('enter a simple mathimatic calculation')
print(ch) # if you enter as 2 + 6 -1 we get output as 2 + 6-1 only
# Out:
# enter a simple mathimatic calculation 2+3+8/5*2
# 2+3+8/5*2

# %%
ch = eval(input('enter a char'))
print(ch) # if you enter as 2 + 6 -1 we get output as 2 + 6-1 only
# Out:
# enter a char 2+3+8/5*2
# 8.2

# %%
pw = input("Enter the password of min 8 char")

print( pw[6:])
# Out:
# Enter the password of min 8 char who is this nonsence
#  this nonsence
