# %% [markdown]
# # Data Type

# %% [markdown]
# # int Float

# %%
x= 101
y = 456
x,y
# Out:
# (101, 456)

# %%
flo = 10.2
type(flo)
# Out:
# float

# %%
type(x)
id(x)
# Out:
# 140733280923688

# %%
import sys
sys.getsizeof(x)
# Out:
# 28

# %%
x=450
x
# Out:
# 450

# %%
sys.getsizeof(x)
# Out:
# 28

# %%
id(x)
# Out:
# 2621068123600

# %%
g = 125E2
g
# Out:
# 12500.0

# %%
k = 2345E-2
k
# Out:
# 23.45

# %%
x =True
y =False
print(x,y)
# Out:
# True False

# %%
int(x)
# Out:
# 1

# %%
int(y)
# Out:
# 0

# %%
type(x)
# Out:
# bool

# %%
a= 10
b = 5
a<b
# Out:
# False

# %%
a==b
# Out:
# False

# %%
a>b
# Out:
# True

# %%
c3 = complex(5,3)
c3
# Out:
# (5+3j)

# %%
int[j]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 int[j]
#
# NameError: name 'j' is not defined

# %%
p = 201
p
# Out:
# 201

# %%
q = 13_52_12_108
q
# Out:
# 135212108

# %%
int(10.5)
# Out:
# 10

# %%
float(2)
# Out:
# 2.0

# %%
int(True)
# Out:
# 1

# %%
a= 20
b=3
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 6.666666666666667
# 6
# 2
# 8000

# %% [markdown]
# # Arthimetic Operations

# %%
a=15
b=2
print(a+b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 17
# 30
# 7.5
# 7
# 1
# 225

# %% [markdown]
# # Program to get area of rectangle when length and breath are given

# %%
length = 10
breath = 2
Area = length*breath
print('Area of length',length,' and','breath',breath ,'is=',Area)
# Out:
# Area of length 10  and breath 2 is= 20

# %%
print(f'Area of {length} and {breath} is {Area}.')

# %%
length = int(input(" Give the length value"))
breath = int(input("Give the breath value"))
Area = (length*breath)
print('Area of length',length,' and','breath',breath ,'is=',Area)
# Out:
#  Give the length value 5
# Give the breath value 2
# Area of length 5  and breath 2 is= 10

# %% [markdown]
# # Program to get the area of Triangle

# %%
base = int(input('Enter base'))
height = int(input('Enter height'))
area = 1/2 * base * height
print('Area is ', area)
# Out:
# Enter base 5
# Enter height 12
# Area is  30.0

# %% [markdown]
# # Arithmetic Assignment Operators

# %%
a=2
b=3
a+=b
print(a)
# Out:
# 5

# %%
a-=b
print(a)
print(b)
# Out:
# 2
# 3

# %%
a*=b
print(a)
# Out:
# 6

# %%
s='abc'
s+10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 s='abc'
# ----> 2 s+10
#
# TypeError: can only concatenate str (not "int") to str

# %%
s+'10'
# Out:
# 'abc10'

# %%
s*10
# Out:
# 'abcabcabcabcabcabcabcabcabcabc'

# %%
s**10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 s**10
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
s1= 'abc'
s2 = 'bcf'
s1+s2
# Out:
# 'abcbcf'

# %%
1+'Mohan'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 1+'Mohan'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
False/True
# Out:
# 0.0

# %%
True+2.5
# Out:
# 3.5

# %%
True +2
# Out:
# 3

# %%
2+3j + 2+5J
# Out:
# (4+8j)

# %% [markdown]
# # conditional Statements

# %% [markdown]
# #Relational Operators

# %%
a='Mohan'
b='Krishna'
a==b
# Out:
# False

# %%
len(a)!=len(b)
# Out:
# True

# %%
a < b
# Out:
# False

# %%
a>b
# Out:
# True

# %% [markdown]
# # conditional statement
#
# ## If <condition>:
#     Statement1
#     Statement2
# ## else:
#     Statement 3
#     statement 4

# %% [markdown]
#  # Getting a number and check it if it is greater than 10 or not if.

# %%
a = int(input("Enter the number"))
if a>=10:
    print('Number',a ,'is greater than 10')
else:
    print('Number',a ,'is not greater than 10')
# Out:
# Enter the number 20
# Number 20 is greater than 10

# %%
a=5
b=7
c=3

a>b and a>c
# Out:
# False

# %%
a>b or a>c
# Out:
# True

# %%
a= 8
a>0 and a<10
# Out:
# True

# %%
not a ==8
# Out:
# False

# %% [markdown]
# # Challange
#  # Check the given number is Even or odd.

# %%
a = int(input("Enter the number"))
if a%2==0:
    print('Number is Even')
else:
    print('Number is Odd')
# Out:
# Enter the number 15
# Number is Odd

# %% [markdown]
# # Challange
#  # Check the age of the e

# %%
'apply'>'apple'
# Out:
# True

# %%
'Apple'>'apple'
# Out:
# False

# %%
5 and 10
# Out:
# 10

# %%
0 and 10
# Out:
# 0

# %%
5 or 10
# Out:
# 5

# %%
0 or 5
# Out:
# 5

# %%
a =3
b= 5
c= 7
d=10
a<b<c
# Out:
# True

# %%
a==b<c
# Out:
# False

# %%
a>b<c>d
# Out:
# False

# %% [markdown]
# # Sets

# %%
s1 = {1,2,3,4,5}
s2 = {4,5,9,10,11}
s1,s2
# Out:
# ({1, 2, 3, 4, 5}, {4, 5, 9, 10, 11})

# %%
s1|s2
# Out:
# {1, 2, 3, 4, 5, 9, 10, 11}

# %%
s1&s2
# Out:
# {4, 5}

# %%
s1&=s2

# %%
s1
# Out:
# {4, 5}

# %%
s1 = {1,2,3,4,5}
s2 = {4,5,9,10,11}
s1,s2
# Out:
# ({1, 2, 3, 4, 5}, {4, 5, 9, 10, 11})

# %%
s3 =s1-s2

# %%
s3
# Out:
# {1, 2, 3}

# %%
s1 = {1,2,3,4,5}
s2 = {4,5,9,10,11}
s1,s2
# Out:
# ({1, 2, 3, 4, 5}, {4, 5, 9, 10, 11})

# %%
s3=s1^s2

# %%
s3
# Out:
# {1, 2, 3, 9, 10, 11}

# %%
s1 = {1,2,3,4,5}
s2 = {4,5,9,10,11}
s1,s2
# Out:
# ({1, 2, 3, 4, 5}, {4, 5, 9, 10, 11})

# %%
s1^=s2

# %%
s1
# Out:
# {1, 2, 3, 9, 10, 11}

# %%
s1 = {1,2,3,4,5}
s2 = {4,5,9,10,11}
s1,s2
# Out:
# ({1, 2, 3, 4, 5}, {4, 5, 9, 10, 11})

# %%
s1.add(s2)
s1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 s1.add(s2)
#       2 s1
#
# TypeError: unhashable type: 'set'

# %%
s1.add(5)
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
s1.update('Mohan')
s1
# Out:
# {'0', 1, '1', 2, 3, 4, 5, 'M', 'a', 'h', 'n', 'o'}

# %%
s1.copy(s2)
s1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 s1.copy(s2)
#       2 s1
#
# TypeError: set.copy() takes no arguments (1 given)

# %%
s1.update((60,70))
s1
# Out:
# {'0', 1, '1', 2, 3, 4, 5, 60, 70, 'M', 'a', 'h', 'n', 'o'}

# %%
s2 = s1.copy()
s2,s1
# Out:
# ({'0', 1, '1', 2, 3, 4, 5, 60, 70, 'M', 'a', 'h', 'n', 'o'},
#  {'0', 1, '1', 2, 3, 4, 5, 60, 70, 'M', 'a', 'h', 'n', 'o'})

# %%
s1.pop()
# Out:
# 1

# %%
s1
# Out:
# {'0', '1', 2, 3, 4, 5, 60, 70, 'M', 'a', 'h', 'n', 'o'}

# %%
s1.pop()
# Out:
# 2

# %%
s1
# Out:
# {'0', '1', 3, 4, 5, 60, 70, 'M', 'a', 'h', 'n', 'o'}

# %%
s1.discard('Mohan')
s1
# Out:
# {'0', '1', 3, 4, 5, 60, 70, 'M', 'a', 'h', 'n', 'o'}

# %%
s1.discard(70)
s1
# Out:
# {'0', '1', 3, 4, 5, 60, 'M', 'a', 'h', 'n', 'o'}

# %%
s1.discard('M')
s1
# Out:
# {'0', '1', 3, 4, 5, 60, 'a', 'h', 'n', 'o'}

# %%
s1.remove('Mohan')
s1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 s1.remove('Mohan')
#       2 s1
#
# KeyError: 'Mohan'

# %%
s1.remove('a')
s1
# Out:
# {'0', '1', 3, 4, 5, 60, 'h', 'n', 'o'}

# %%
s1.clear()
s1
# Out:
# set()

# %%
s1
# Out:
# set()

# %%
del s1

# %%
s1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 s1
#
# NameError: name 's1' is not defined

# %% [markdown]
# # Loops

# %%
n =5
while(n>0):
    print(n)
    n=n-1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
n=3
i=1
while(i<=10):
    print(n,'X',i, '=',i*n)
    i=i+1
# Out:
# 3 X 1 = 3
# 3 X 2 = 6
# 3 X 3 = 9
# 3 X 4 = 12
# 3 X 5 = 15
# 3 X 6 = 18
# 3 X 7 = 21
# 3 X 8 = 24
# 3 X 9 = 27
# 3 X 10 = 30

# %%
n=1435
while n>0:
    r=n%10
    print(r)
    n=n//10
# Out:
# 5
# 3
# 4
# 1
